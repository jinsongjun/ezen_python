# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.5 MB 100.9 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/5.5 MB 131.3 kB/s eta 0:00:42
#      ---------------------------------------- 0.1/5.5 MB 164.1 kB/s eta 0:00:33
#      ---------------------------------------- 0.1/5.5 MB 164.1 kB/s eta 0:00:33
#       --------------------------------------- 0.1/5.5 MB 194.6 kB/s eta 0:00:28
#      - -------------------------------------- 0.2/5.5 MB 306.3 kB/s eta 0:00:18
#      -------------- ------------------------- 2.0/5.5 MB 3.8 MB/s eta 0:00:01
# ...

# %%
# %matplotlib inline

# jupyter의 code cell에서 print() 함수 호출 없이, (복수의)변수명만 입력하면 해당 변수들의 값들이 한번에 출력이 되도록 해주는 설정입니다.
# 구글에 "multiple output in jupyter withtout print()" 로 검색하면 나오는 코드 중에 하나이니, 딱히 외우거나 하시지 않아도 됩니다.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np
pd.set_option('display.float_format', lambda x: '%.3f' % x)    # DataFrame 숫자데이터가 소수점 셋째자리까지 나오도록 설정
pd.set_option('max_columns', None)  # DataFrame에서 모든 컬럼을 다 볼 수 있게 설정

from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[2], line 11
#       9 import numpy as np
#      10 pd.set_option('display.float_format', lambda x: '%.3f' % x)    # DataFrame 숫자데이터가 소수점 셋째자리까지 나오도록 설정
# ---> 11 pd.set_option('max_columns', None)  # DataFrame에서 모든 컬럼을 다 볼 수 있게 설정
#      13 from datetime import datetime
#
# File c:\Users\PC\anaconda3\Lib\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File c:\Users\PC\anaconda3\Lib\site-packages\pandas\_config\config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
# ...

# %%
from datetime import datetime

# %%
datetime(2024,1,16)
type(datetime(2024,1,16))
# Out:
# datetime.datetime(2024, 1, 16, 0, 0)
# datetime.datetime

# %%
a = datetime(2014, 8, 1)
b = pd.Timestamp(a)
b
# Out:
# Timestamp('2014-08-01 00:00:00')

# %%
dates = [datetime(2014, 8, 1) , datetime(2024, 1, 16)]
dti = pd.DatetimeIndex(dates)
dti
# Out:
# DatetimeIndex(['2014-08-01', '2024-01-16'], dtype='datetime64[ns]', freq=None)

# %%
dti_1 = pd.to_datetime(dates)

# %%
dti_1
# Out:
# DatetimeIndex(['2014-08-01', '2024-01-16'], dtype='datetime64[ns]', freq=None)

# %%
type(pd.to_datetime(dates)[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
[datetime(2014, 8, 1) , datetime(2024, 1, 16)]
ts = pd.Series(np.random.randn(2), index=dates)
# Out:
# [datetime.datetime(2014, 8, 1, 0, 0), datetime.datetime(2024, 1, 16, 0, 0)]

# %%
ts
# Out:
# 2014-08-01   -1.009
# 2024-01-16    1.474
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2014-08-01', '2024-01-16'], dtype='datetime64[ns]', freq=None)

# %%
type(ts.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
import numpy as np

# %%
dates = [datetime(2014, 8, 1), datetime(2014, 8, 5)]
ts = pd.Series(np.random.randn(2), index=dates)
ts
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
ts
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
ts.loc[pd.Timestamp("2014-08-01")]
# Out:
# 0.5408578749861275

# %%
ts.loc["2014-08-01"]
# Out:
# 0.5408578749861275

# %%
ts = ts.sort_index()

# %%
ts
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
ts.loc['2014-08']
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
ts.loc['2014-08-02':'2014-08-31']
# Out:
# 2014-08-05   0.967
# dtype: float64

# %%
ts.loc["2014-08-01":"2014-08-05"]
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
ts.loc['2014-08-02':]
# Out:
# 2014-08-05   0.967
# dtype: float64

# %%
ts.iloc[[0,1]]
# Out:
# 2014-08-01   0.541
# 2014-08-05   0.967
# dtype: float64

# %%
dates = pd.date_range('2014-08-01' , periods=10, freq="D")

# %%
dates
# Out:
# DatetimeIndex(['2014-08-01', '2014-08-02', '2014-08-03', '2014-08-04',
#                '2014-08-05', '2014-08-06', '2014-08-07', '2014-08-08',
#                '2014-08-09', '2014-08-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2024-01-12' , periods=10, freq="B")

# %%
dates
# Out:
# DatetimeIndex(['2024-01-12', '2024-01-15', '2024-01-16', '2024-01-17',
#                '2024-01-18', '2024-01-19', '2024-01-22', '2024-01-23',
#                '2024-01-24', '2024-01-25'],
#               dtype='datetime64[ns]', freq='B')

# %%
dates = pd.date_range('2014-08-01' , '2014-08-14', freq="D")
dates
# Out:
# DatetimeIndex(['2014-08-01', '2014-08-02', '2014-08-03', '2014-08-04',
#                '2014-08-05', '2014-08-06', '2014-08-07', '2014-08-08',
#                '2014-08-09', '2014-08-10', '2014-08-11', '2014-08-12',
#                '2014-08-13', '2014-08-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
period = pd.Period('2014-08' , freq='Q')
period
# Out:
# Period('2014Q3', 'Q-DEC')

# %%
period.start_time
period.end_time
# Out:
# Timestamp('2014-07-01 00:00:00')
# Timestamp('2014-09-30 23:59:59.999999999')

# %%
period2 = period + 1
period2.start_time
period2.end_time
# Out:
# Timestamp('2014-10-01 00:00:00')
# Timestamp('2014-12-31 23:59:59.999999999')

# %%
p2013 = pd.period_range('2013-01-01' , '2013-12-31' , freq='m')
p2013
# Out:
# PeriodIndex(['2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06',
#              '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12'],
#             dtype='period[M]')

# %%
p2013[0]
# Out:
# Period('2013-01', 'M')

# %%
for i in p2013 :
    print("{0} {1} {2} {3}".format(i, i.freq , i.start_time , i.end_time))
# Out:
# 2013-01 <MonthEnd> 2013-01-01 00:00:00 2013-01-31 23:59:59.999999999
# 2013-02 <MonthEnd> 2013-02-01 00:00:00 2013-02-28 23:59:59.999999999
# 2013-03 <MonthEnd> 2013-03-01 00:00:00 2013-03-31 23:59:59.999999999
# 2013-04 <MonthEnd> 2013-04-01 00:00:00 2013-04-30 23:59:59.999999999
# 2013-05 <MonthEnd> 2013-05-01 00:00:00 2013-05-31 23:59:59.999999999
# 2013-06 <MonthEnd> 2013-06-01 00:00:00 2013-06-30 23:59:59.999999999
# 2013-07 <MonthEnd> 2013-07-01 00:00:00 2013-07-31 23:59:59.999999999
# 2013-08 <MonthEnd> 2013-08-01 00:00:00 2013-08-31 23:59:59.999999999
# 2013-09 <MonthEnd> 2013-09-01 00:00:00 2013-09-30 23:59:59.999999999
# 2013-10 <MonthEnd> 2013-10-01 00:00:00 2013-10-31 23:59:59.999999999
# 2013-11 <MonthEnd> 2013-11-01 00:00:00 2013-11-30 23:59:59.999999999
# 2013-12 <MonthEnd> 2013-12-01 00:00:00 2013-12-31 23:59:59.999999999

# %%
a = pd.date_range('1/1/2013', '12/31/2013', freq='M')
a
a[0]
# Out:
# DatetimeIndex(['2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30',
#                '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31',
#                '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31'],
#               dtype='datetime64[ns]', freq='M')
# Timestamp('2013-01-31 00:00:00')

# %%
b = pd.period_range('1/1/2013', '12/31/2013', freq='M')
b
b[0]
# Out:
# PeriodIndex(['2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06',
#              '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12'],
#             dtype='period[M]')
# Period('2013-01', 'M')

# %%
ps = pd.Series(np.random.randn(12), p2013)
ps
# Out:
# 2013-01   -0.093
# 2013-02    0.061
# 2013-03    1.139
# 2013-04   -0.625
# 2013-05    0.447
# 2013-06   -1.155
# 2013-07   -0.255
# 2013-08   -1.045
# 2013-09    1.306
# 2013-10   -0.450
# 2013-11    0.293
# 2013-12   -0.971
# Freq: M, dtype: float64

# %%
ps.loc['2013-11']
# Out:
# -0.15403606809395134

# %%
ps.loc['2013-11':]
# Out:
# 2013-11    0.293
# 2013-12   -0.971
# Freq: M, dtype: float64

# %%
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
df = pd.DataFrame(
    {
        "price":[1, 1.02, 1.01, 1.05],
    },
    index=[1,2,3,4]
)
df
# Out:
#    price
# 1 1.0000
# 2 1.0200
# 3 1.0100
# 4 1.0500
