# %% [markdown]
# ### openapi
# - 웹 주소로 요청을 보낸 뒤 응답 메시지를 확인
# - requests 라이브러리를 이용하여 요청을 보내고 응답 메시지를 받는다.

# %%
import requests

# %%
# !pip install requests

# %%
# google에 요청
url = "https://www.google.com"

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="9UxTL3uhBl2pFsT6HBQgqA">(function(){var _g={kEI:\'CPiZZaTwK8zl1e8PvrS5kA8\',kEXPI:\'0,56482,736862,4882,3,567238,207,4804,1132070,870537,327168,380785,16115,28684,23792,12318,17581,4998,17075,38444,2872,2891,11754,606,50059,10631,2614,13491,230,20583,4,59617,27053,6621,7596,1,42154,2,39761,5679,1021,31122,4568,6255,23421,1252,33064,2,2,1,24626,2006,8155,23350,20507,7,1922,9779,42459,20198,20137,14,82,47824,5122,3030,15816,1804,13806,21187,275,11814,476,1159,13493,5251990,1015,2,366,1105,115,5992170,530,679,2806666,7475460,5,19234362,1305642,16673,43886,3,1603,3,262,3,234,3,2121276,2585,23029351,12799,8408,6578,2323,5799,1403,2,560,13023,4427,10577,5878,14606,8781,1297,6308,9213,2,1010,286,2052,27,6,5,15,
# ...

# %%
url = 'http://apis.data.go.kr/1160100/service/GetFnCoBasiInfoService/getFnCoOutl'

params = {
    'serviceKey' : 'dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw==', 
    'pageNo' : '1', 
    'numOfRows' : '10', 
    'resultType' : 'xml'
}

response = requests.get(url, params=params)

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response>\n    <header>\n        <resultCode>00</resultCode>\n        <resultMsg>NORMAL SERVICE.</resultMsg>\n    </header>\n    <body>\n        <numOfRows>10</numOfRows>\n        <pageNo>1</pageNo>\n        <totalCount>1312705</totalCount>\n        <items>\n            <item>\n                <actnAudpnNm>\xec\x82\xbc\xec\x9d\xbc\xed\x9a\x8c\xea\xb3\x84\xeb\xb2\x95\xec\x9d\xb8</actnAudpnNm>\n                <audtRptOpnnCtt>\xec\xa0\x81\xec\xa0\x95\xec\x9d\x98\xea\xb2\xac</audtRptOpnnCtt>\n                <basDt>20200408</basDt>\n                <bzno>2028116825</bzno>\n                <corpRegMrktDcd>P</corpRegMrktDcd>\n                <corpRegMrktDcdNm>\xec\x9c\xa0\xea\xb0\x80</corpRegMrktDcdNm>\n                <crno>1101110002959</crno>\n                <empeAvgCnwkTermCtt>10</empeAvgCnwkTermCtt>\n                <fncoAdr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa4\x91\xea\xb5\xac  \xec\xb2\xad\
# ...

# %%
from pprint import pprint

# %%
pprint(response.content)

# %%
# xml 데이터를 dict 형태로 변환하기 위한 라이브러리 설치 
# !pip install xmltodict

# %%
import xmltodict

# %%
data = xmltodict.parse(response.content)

data

# %%
data2 = data['response']['body']['items']['item']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data2)

# %%
df.columns
# Out:
# Index(['actnAudpnNm', 'audtRptOpnnCtt', 'basDt', 'bzno', 'corpRegMrktDcd',
#        'corpRegMrktDcdNm', 'crno', 'empeAvgCnwkTermCtt', 'fncoAdr',
#        'fncoEmpeAvgSlryAmt', 'fncoEmpeCnt', 'fncoEnsnNm', 'fncoEstbDt',
#        'fncoFxno', 'fncoHmpgUrl', 'fncoKosdaqLstgAbolDt', 'fncoKosdaqLstgDt',
#        'fncoKrxLstgAbolDt', 'fncoKrxLstgDt', 'fncoMainBizNm', 'fncoNm',
#        'fncoRprNm', 'fncoSmenpYn', 'fncoStacMm', 'fncoTlno',
#        'fncoXchgLstgAbolDt', 'fncoXchgLstgDt', 'fncoZpcd', 'fssCorpChgDtm',
#        'fssCorpUnqNo', 'isinCd', 'isinCdNm', 'mntrFcnFncoCd',
#        'mntrFcnFncoCdNm', 'sicCd', 'sicNm'],
#       dtype='object')

# %%
# 데이터프레임을 csv로 저장(데이터의 형태를 데이터프레임에서 csv의 형태로 변환)
df.to_csv('금융회사기본정보.csv', index=False)
